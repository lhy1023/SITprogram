# %% [markdown]
# ### 简介
# 此版本为综合v1中两种方法采集到的所有可用信息作为数据集。
#
# 输入主要包含：
# 1. 脸部图片
# 2. 眼部部分截图
# 3. 提取出的脸部信息（左右宽度比，上下高度比）
#
# 输出：鼠标位置的横、纵坐标
#
# 主要更新内容：
# 路径保存问题，时间戳命名，csv内容
#
# 注意事项：
# 1. 当前版本中，通过摄像头采集照片，和采集照片后进行加工处理的两部分必须挨着完成，即不能从其他途径引入命名格式不同，或获取时间不同的图片（由于采用仅存于内存中的数据结构保存关键数据）

# %%
#引入所有需要的模块，如有未安装的库建议pip install
# PyAutoGUI是一个纯Python的GUI自动化工具，其目的是可以用程序自动控制鼠标和键盘操作，多平台支持（Windows，OS X，Linux）。
#cv2即opencv2，用于实现电脑摄像头的调用等操作
#PIL 为Python 常用图像处理模块
import pyautogui as pag
import time
import requests
import os
import cv2
import urllib3,base64
import json
from PIL import Image
from urllib.parse import urlencode
import csv
import threading
import time

# %% [markdown]
# ###  一、收集并保存摄像头照片
# 通过openCV调用摄像头，**在按下空格键时保存照片**，命名为鼠标所在位置的元组形式。
#
# 运行此单元格后将弹出名为Capture的摄像头视频页面，敲击空格即可保存图片，通过ESC键终止运行。

# %%
#初始化相关数据文件夹和暂存用数据结构
paths = ['./dataset_origin/','./dataset_face/','./dataset_eye/']
for path in paths:
    if not os.path.exists(path):
        os.makedirs(path)
#存放图片时间戳（字符串形式，固定为10位）和对应鼠标坐标（元组形式）
photoDic = {}
# 存放csv文件的原始数据，每行五列，对应图片名（时间戳），额外参数（paramX,paramY),鼠标横、纵坐标
rows = []

# %%
#获取屏幕大小
screenWidth,screenHeight = pag.size()
#计算获得屏幕原点位置，定为屏幕中心点
origin = (screenWidth/2,screenHeight/2)

cap=cv2.VideoCapture(0) #调用摄像头，0为电脑自带摄像头，1为外部摄像头
cccount=0#自动获取图片
while(1):
    ret,frame = cap.read()
    k=cv2.waitKey(1)
    if k==27: #Esc键退出
        break
#    elif k==32:#空格键保存图片
    elif cccount < 199:
        cccount+=1
        time.sleep(0.1)
        #获取当前鼠标绝对位置
        currMouseX,currMouseY = pag.position() 
        #将鼠标绝对位置转化为相对于原点的相对坐标，并进行归一化处理
        #对归一化处理有疑惑可参考：https://www.jianshu.com/p/95a8f035c86c
        currMouse = ((currMouseX-origin[0])/origin[0],(origin[1]-currMouseY)/origin[1])
        #调用python自带的库time，快捷地获取当前时间生成时间戳
        curr_time = str(int(time.time()))
        
        ccount=str(cccount)
        
        if cccount<10:
            ccount='00'+str(cccount)
        elif cccount<100:
            ccount='0'+str(cccount)
        else:
            ccount=str(cccount)
        #将图片的命名信息和对应鼠标坐标暂时保存至此字典中
        photoDic[ccount] = currMouse
        
        
        cv2.imwrite(paths[0]+ ccount +'.jpg',frame)
            
        print(curr_time) #方便调试，若成功保存则会立刻在控制台输出
    cv2.imshow("capture", frame)
cap.release()
cv2.destroyAllWindows()
# Out:
# 1613997941
# 1613997941
# 1613997941
# 1613997941
# 1613997942
# 1613997942
# 1613997942
# 1613997942
# 1613997942
# 1613997942
# 1613997942
# 1613997942
# 1613997942
# 1613997943
# 1613997943
# 1613997943
# 1613997943
# 1613997943
# 1613997943
# 1613997943
# 1613997943
# 1613997943
# 1613997944
# 1613997944
# 1613997944
# 1613997944
# 1613997944
# 1613997944
# 1613997944
# 1613997944
# 1613997944
# 1613997945
# 1613997945
# 1613997945
# 1613997945
# 1613997945
# 1613997945
# 1613997945
# 1613997945
# 1613997946
# 1613997946
# 1613997946
# 1613997946
# 1613997946
# 1613997946
# 1613997946
# 1613997946
# 1613997946
# 1613997947
# 1613997947
# 1613997947
# 1613997947
# 1613997947
# 1613997947
# 1613997947
# 1613997947
# 1613997947
# 1613997948
# 1613997948
# 1613997948
# 1613997948
# 1613997948
# 1613997948
# 1613997948
# 1613997948
# 1613997948
# 1613997949
# 1613997949
# 1613997949
# 1613997949
# 1613997949
# 1613997949
# 1613997949
# 1613997949
# 1613997950
# 1613997950
# 1613997950
# 1613997950
# 1613997950
# 1613997950
# 1613997950
# 1613997950
# 1613997950
# 1613997951
# 1613997951
# 1613997951
# 1613997951
# 1613997951
# 1613997951
# 1613997951
# 1613997951
# 1613997951
# 1613997952
# 1613997952
# 1613997952
# 1613997952
# 1613997952
# 1613997952
# 1613997952
# 1613997952
# 1613997952
# 1613997953
# 1613997953
# 1613997953
# 1613997953
# 1613997953
# 1613997953
# 1613997953
# 1613997953
# 1613997953
# 1613997954
# 1613997954
# 1613997954
# 1613997954
# 1613997954
# 1613997954
# 1613997954
# 1613997954
# 1613997955
# 1613997955
# 1613997955
# 1613997955
# 1613997955
# 1613997955
# 1613997955
# 1613997955
# 1613997955
# 1613997956
# 1613997956
# 1613997956
# 1613997956
# 1613997956
# 1613997956
# 1613997956
# 1613997956
# 1613997956
# 1613997957
# 1613997957
# 1613997957
# 1613997957
# 1613997957
# 1613997957
# 1613997957
# 1613997957
# 1613997957
# 1613997958
# 1613997958
# 1613997958
# 1613997958
# 1613997958
# 1613997958
# 1613997958
# 1613997958
# 1613997959
# 1613997959
# 1613997959
# 1613997959
# 1613997959
# 1613997959
# 1613997959
# 1613997959
# 1613997959
# 1613997960
# 1613997960
# 1613997960
# 1613997960
# 1613997960
# 1613997960
# 1613997960
# 1613997960
# 1613997960
# 1613997961
# 1613997961
# 1613997961
# 1613997961
# 1613997961
# 1613997961
# 1613997961
# 1613997961
# 1613997961
# 1613997962
# 1613997962
# 1613997962
# 1613997962
# 1613997962
# 1613997962
# 1613997962
# 1613997962
# 1613997963
# 1613997963
# 1613997963
# 1613997963
# 1613997963
# 1613997963
# 1613997963
# 1613997963
# 1613997963
# 1613997964
# 1613997964

# %% [markdown]
# ### 二、调用人脸识别API获取关键点信息
# 调用百度AI-人脸识别以照片进行处理，并找出照片中的脸部关键点信息，以方便对图片信息进行下一步的处理。
#
# BaiduAI 相关技术文档：https://ai.baidu.com/ai-doc/FACE/yk37c1u4t
#
# 注：此方法仅支持2QPS的查询率（即每秒2次的查询率），如需实际应用或用于实时演示则需更改此部分的代码或购买更大的处理能力。也可通过申请多个百度账号，建立账号池以增大qps。

# %%
# 首先通过百度AI提供的方法获取申请服务时的ID参数access_token，此参数至少一个月需更新一次，此处提供的为我的access_token
import requests 

# client_id 为官网获取的AK， client_secret 为官网获取的SK
host = 'https://aip.baidubce.com/oauth/2.0/token?grant_type=client_credentials&client_id=QGsRMBXewEr9zcmapc3HeIVC&client_secret=PloEXIBs9Sf30tYVVtOppftGGgnqTwNh'
access_token = 'wait_to_get'
response = requests.get(host)
if response:
    access_token = response.json()['access_token']
    print(access_token)

#BaiduAI 人脸关键点识别方法调用，参数为文件路径，返回json格式的BaiduAI的反馈
def BaiduMethod(filepath):
    file = open(filepath,'rb')
    img =  open(filepath,'rb')
    #参数images：图像base64编码 分别base64编码后的2张图片数据，需urlencode，半角逗号分隔，单次请求最大不超过20M
    img1 = base64.b64encode(img.read())
    request_url = "https://aip.baidubce.com/rest/2.0/face/v3/detect"+ "?access_token=" + access_token
    params = {'image':str(img1,'utf-8'),'image_type':'BASE64','face_field':'landmark'}
    headers = {'content-type': 'application/json'}
    return requests.post(request_url, data=params, headers=headers)
# Out:
# 24.cf374d791207f2d037389c3b6e6ccbfd.2592000.1616589996.282335-22192901

# %%
#测试用，可忽略
#此处改为所想读取的单个图片
filepath = paths[0]+'1613652963.jpg'
#考虑到百度AI平台的对并发量的限制，此处推荐分开处理，即获取response后不再重复对同一张照片进行处理
response = BaiduMethod(filepath)
if response:
    print (response.json())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-37259744f169> in <module>
#       3 filepath = paths[0]+'1613652963.jpg'
#       4 #考虑到百度AI平台的对并发量的限制，此处推荐分开处理，即获取response后不再重复对同一张照片进行处理
# ----> 5 response = BaiduMethod(filepath)
#       6 if response:
#       7     print (response.json())
#
# <ipython-input-6-45465d2590b5> in BaiduMethod(filepath)
#      12 #BaiduAI 人脸关键点识别方法调用，参数为文件路径，返回json格式的BaiduAI的反馈
#      13 def BaiduMethod(filepath):
# ---> 14     file = open(filepath,'rb')
#      15     img =  open(filepath,'rb')
#      16     #参数images：图像base64编码 分别base64编码后的2张图片数据，需urlencode，半角逗号分隔，单次请求最大不超过20M
#
# FileNotFoundError: [Errno 2] No such file or directory: './dataset_origin/1613652963.jpg'

# %% [markdown]
# <center>关键点识别图片</center>
# <img src='https://ai.bdstatic.com/file/52BC00FFD4754A6298D977EDAD033DA0' width = '75%'>

# %% [markdown]
# ### 三、根据已有信息生成数据集
# 数据集格式：
# 图片命名均为时间戳
# 1. ./dataset_origin/ 存放摄像头保存的原始照片
# 2. ./dataset_face/ 存放整张脸的照片，命名为当前时间戳
# 3. ./dataset_eye/ 存放眼部照片，截取的范围可进一步精确
# 4. ./dataset_csv 存放图片解析的额外信息(左右宽度比，上下高度比）和图片输出的鼠标横纵坐标

# %%
#定义图片加工方法
#处理dataset_origin中的原始图片，得到相同命名，存放路径不同的脸部和眼部图片。
def imgCrop(landmark,img):
    box = (landmark[0]['x'],landmark[24]['y'],landmark[12]['x'],landmark[6]['y'])#截取脸部图片
    box2 = (landmark[22]['x'],landmark[22]['y'],landmark[22]['x']+150,landmark[22]['y']+50) #截取眼部图片
    img2 = img.crop(box)
    img3 = img.crop(box2)
    #     img2.show() #实时显示切割图片方便微调
    img2.save(paths[1]+file) # 存放脸部帐篷
    img3.save(paths[2]+file) #存放眼部照片
    
#定义图片解析方法
def imgAnalyse(landmark,file):
#      参数一：左半脸与右半脸宽度之比（相对观察者而言的左右）
    paramX = abs(landmark[0]['x']-landmark[57]['x'])/abs(landmark[12]['x']-landmark[57]['x'])
#       参数二：鼻尖与眼部上侧坐标纵坐标差值(建议进行进一步改进)
    eyeY = (landmark[15]['y'] + landmark[32]['y'])/2
    paramY = eyeY - landmark[57]['y']
    return (paramX,paramY)

# %%
#遍历原始照片照片文件夹，调用 baidu 方法进行人脸分析，并根据反馈信息进行加工处理
dirs = os.listdir(paths[0])
for file in dirs:
    if(file=='.ipynb_checkpoints'):
        continue
    filepath = os.path.join(paths[0],file)
    print(filepath)
#     filepath = os.getcwd()+'\dataset_orgin\'+file
    #调用BaiduAi 方法获取json包
    response = BaiduMethod(filepath) 
    if response and response.json()['error_code']==0:#成功收到且未报错
        landmark = response.json()['result']['face_list'][0]['landmark72']
        img = Image.open(filepath)
        imgCrop(landmark,img)
        param = imgAnalyse(landmark,file)
        # 一行数据格式为：文件名，额外参数，鼠标坐标
        fileName = file[0:3] 
        mouse = photoDic[fileName]
        rows.append([fileName,param[0],param[1],mouse[0],mouse[1]])

#将获得的数据写入csv文件中
headers = ['fileName','paramX','paramY','mouseX','mouseY']
with open('dataset.csv','w') as f:
    f_csv = csv.writer(f)
    f_csv.writerow(headers)
    f_csv.writerows(rows)
# Out:
# ./dataset_origin/001.jpg
# ./dataset_origin/002.jpg
# ./dataset_origin/003.jpg
# ./dataset_origin/004.jpg
# ./dataset_origin/005.jpg
# ./dataset_origin/006.jpg
# ./dataset_origin/007.jpg
# ./dataset_origin/008.jpg
# ./dataset_origin/009.jpg
# ./dataset_origin/010.jpg
# ./dataset_origin/011.jpg
# ./dataset_origin/012.jpg
# ./dataset_origin/013.jpg
# ./dataset_origin/014.jpg
# ./dataset_origin/015.jpg
# ./dataset_origin/016.jpg
# ./dataset_origin/017.jpg
# ./dataset_origin/018.jpg
# ./dataset_origin/019.jpg
# ./dataset_origin/020.jpg
# ./dataset_origin/021.jpg
# ./dataset_origin/022.jpg
# ./dataset_origin/023.jpg
# ./dataset_origin/024.jpg
# ./dataset_origin/025.jpg
# ./dataset_origin/026.jpg
# ./dataset_origin/027.jpg
# ./dataset_origin/028.jpg
# ./dataset_origin/029.jpg
# ./dataset_origin/030.jpg
# ./dataset_origin/031.jpg
# ./dataset_origin/032.jpg
# ./dataset_origin/033.jpg
# ./dataset_origin/034.jpg
# ./dataset_origin/035.jpg
# ./dataset_origin/036.jpg
# ./dataset_origin/037.jpg
# ./dataset_origin/038.jpg
# ./dataset_origin/039.jpg
# ./dataset_origin/040.jpg
# ./dataset_origin/041.jpg
# ./dataset_origin/042.jpg
# ./dataset_origin/043.jpg
# ./dataset_origin/044.jpg
# ./dataset_origin/045.jpg
# ./dataset_origin/046.jpg
# ./dataset_origin/047.jpg
# ./dataset_origin/048.jpg
# ./dataset_origin/049.jpg
# ./dataset_origin/050.jpg
# ./dataset_origin/051.jpg
# ./dataset_origin/052.jpg
# ./dataset_origin/053.jpg
# ./dataset_origin/054.jpg
# ./dataset_origin/055.jpg
# ./dataset_origin/056.jpg
# ./dataset_origin/057.jpg
# ./dataset_origin/058.jpg
# ./dataset_origin/059.jpg
# ./dataset_origin/060.jpg
# ./dataset_origin/061.jpg
# ./dataset_origin/062.jpg
# ./dataset_origin/063.jpg
# ./dataset_origin/064.jpg
# ./dataset_origin/065.jpg
# ./dataset_origin/066.jpg
# ./dataset_origin/067.jpg
# ./dataset_origin/068.jpg
# ./dataset_origin/069.jpg
# ./dataset_origin/070.jpg
# ./dataset_origin/071.jpg
# ./dataset_origin/072.jpg
# ./dataset_origin/073.jpg
# ./dataset_origin/074.jpg
# ./dataset_origin/075.jpg
# ./dataset_origin/076.jpg
# ./dataset_origin/077.jpg
# ./dataset_origin/078.jpg
# ./dataset_origin/079.jpg
# ./dataset_origin/080.jpg
# ./dataset_origin/081.jpg
# ./dataset_origin/082.jpg
# ./dataset_origin/083.jpg
# ./dataset_origin/084.jpg
# ./dataset_origin/085.jpg
# ./dataset_origin/086.jpg
# ./dataset_origin/087.jpg
# ./dataset_origin/088.jpg
# ./dataset_origin/089.jpg
# ./dataset_origin/090.jpg
# ./dataset_origin/091.jpg
# ./dataset_origin/092.jpg
# ./dataset_origin/093.jpg
# ./dataset_origin/094.jpg
# ./dataset_origin/095.jpg
# ./dataset_origin/096.jpg
# ./dataset_origin/097.jpg
# ./dataset_origin/098.jpg
# ./dataset_origin/099.jpg
# ./dataset_origin/100.jpg
# ./dataset_origin/101.jpg
# ./dataset_origin/102.jpg
# ./dataset_origin/103.jpg
# ./dataset_origin/104.jpg
# ./dataset_origin/105.jpg
# ./dataset_origin/106.jpg
# ./dataset_origin/107.jpg
# ./dataset_origin/108.jpg
# ./dataset_origin/109.jpg
# ./dataset_origin/110.jpg
# ./dataset_origin/111.jpg
# ./dataset_origin/112.jpg
# ./dataset_origin/113.jpg
# ./dataset_origin/114.jpg
# ./dataset_origin/115.jpg
# ./dataset_origin/116.jpg
# ./dataset_origin/117.jpg
# ./dataset_origin/118.jpg
# ./dataset_origin/119.jpg
# ./dataset_origin/120.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-273132d4ee2f> in <module>
#       8 #     filepath = os.getcwd()+'\dataset_orgin\'+file
#       9     #调用BaiduAi 方法获取json包
# ---> 10     response = BaiduMethod(filepath)
#      11     if response and response.json()['error_code']==0:#成功收到且未报错
#      12         landmark = response.json()['result']['face_list'][0]['landmark72']
#
# <ipython-input-103-45465d2590b5> in BaiduMethod(filepath)
#      19     params = {'image':str(img1,'utf-8'),'image_type':'BASE64','face_field':'landmark'}
#      20     headers = {'content-type': 'application/json'}
# ---> 21     return requests.post(request_url, data=params, headers=headers)
#
# D:\SOFTWARE\ANACONDA_install\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     114     """
#     115
# --> 116     return request('post', url, data=data, json=json, **kwargs)
#     117
#     118
#
# D:\SOFTWARE\ANACONDA_install\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# D:\SOFTWARE\ANACONDA_install\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# D:\SOFTWARE\ANACONDA_install\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# D:\SOFTWARE\ANACONDA_install\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# D:\SOFTWARE\ANACONDA_install\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# D:\SOFTWARE\ANACONDA_install\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     374         # Trigger any extra validation we need to do.
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#     378             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# D:\SOFTWARE\ANACONDA_install\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     992         # Force connect early to allow us to validate the connection.
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#     996         if not conn.is_verified:
#
# D:\SOFTWARE\ANACONDA_install\lib\site-packages\urllib3\connection.py in connect(self)
#     358             ca_cert_dir=self.ca_cert_dir,
#     359             server_hostname=server_hostname,
# --> 360             ssl_context=context,
#     361         )
#     362
#
# D:\SOFTWARE\ANACONDA_install\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     334     if ca_certs or ca_cert_dir:
#     335         try:
# --> 336             context.load_verify_locations(ca_certs, ca_cert_dir)
#     337         except IOError as e:  # Platform-specific: Python 2.7
#     338             raise SSLError(e)
#
# D:\SOFTWARE\ANACONDA_install\lib\site-packages\urllib3\contrib\pyopenssl.py in load_verify_locations(self, cafile, capath, cadata)
#     451         if capath is not None:
#     452             capath = capath.encode("utf-8")
# --> 453         self._ctx.load_verify_locations(cafile, capath)
#     454         if cadata is not None:
#     455             self._ctx.load_verify_locations(BytesIO(cadata))
#
# D:\SOFTWARE\ANACONDA_install\lib\site-packages\OpenSSL\SSL.py in load_verify_locations(self, cafile, capath)
#     787
#     788         load_result = _lib.SSL_CTX_load_verify_locations(
# --> 789             self._context, cafile, capath
#     790         )
#     791         if not load_result:
#
# KeyboardInterrupt:
